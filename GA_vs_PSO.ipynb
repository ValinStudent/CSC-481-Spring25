# %% [markdown]
# <a href="https://colab.research.google.com/github/ValinStudent/CSC-481-Spring25/blob/main/GA_vs_PSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ValinStudent/CSC481-Project
# Out:
# Cloning into 'CSC481-Project'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 128 (delta 24), reused 119 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 161.83 KiB | 5.06 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# !pip install -r CSC481-Project/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 44.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...

# %%
# !python ./CSC481-Project/GA_v_PSO.py
# Out:
# Figure(1000x1000)
#
# ===== BEST PATH FOUND =====
# [(1, 0), (2, 0), (3, 1), (4, 2), (5, 3), (6, 4), (7, 5), (8, 6), (9, 7), (9, 8), (9, 9)]
#
# ===== OBSTACLE LOCATIONS =====
# {(np.int64(3), np.int64(4)), (np.int64(4), np.int64(9)), (np.int64(4), np.int64(6)), (np.int64(9), np.int64(2)), (np.int64(5), np.int64(7)), (np.int64(5), np.int64(1)), (np.int64(7), np.int64(4)), (np.int64(6), np.int64(5)), (np.int64(3), np.int64(9)), (np.int64(5), np.int64(9)), (np.int64(0), np.int64(1)), (np.int64(0), np.int64(7)), (np.int64(2), np.int64(1)), (np.int64(1), np.int64(5)), (np.int64(6), np.int64(7)), (np.int64(5), np.int64(2)), (np.int64(5), np.int64(5)), (np.int64(1), np.int64(1)), (np.int64(2), np.int64(3))}
#
# ===== PATH VALIDATION =====
# ✅ The best path does NOT contain obstacles.
# iteration 0: best fitness = 1.997612595959395
# iteration 1: best fitness = 1.997612595959395
# iteration 2: best fitness = 1.997612595959395
# iteration 3: best fitness = 1.997612595959395
# ...
